# %% [markdown]
# <a href="https://colab.research.google.com/github/ArielTeza/Visualisasi-data/blob/main/transaksi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calendar

# %%
data_transaksi = pd.read_csv("/content/sample_data/transaksi.csv" , names=['Date', 'ID', 'Quantity', 'Price'])
data_transaksi
# Out:
#                      Date     ID  Quantity  Price
# 0     2017-05-03 11:43:20  22704        25  15572
# 1     2017-09-04 07:16:20  22081        10  12461
# 2     2017-07-09 11:39:20  22989       100  12590
# 3     2017-03-20 12:18:20  22629        64  16839
# 4     2018-01-24 08:50:20  21615         1  13596
# ...                   ...    ...       ...    ...
# 7464  2018-01-24 09:17:20  22510         1  18156
# 7465  2018-02-02 09:49:20  20771         2  14606
# 7466  2017-03-23 12:52:20  22493        12  17001
# 7467  2017-10-25 10:28:20  23118         2  15856
# 7468  2017-07-19 09:54:20  23184         2  14769
#
# [7469 rows x 4 columns]

# %%
data_transaksi['Date'] = pd.to_datetime(data_transaksi['Date'])
data_transaksi['year'] = data_transaksi['Date'].dt.year
data_transaksi['month'] = data_transaksi['Date'].dt.month_name()

data_year = data_transaksi[data_transaksi['year'] == 2017]
data_year

plt.scatter(data_year['month'], data_year['Quantity'])

plt.xlabel('Month')
plt.ylabel('Quantity')
plt.title('Transaksi pada tahun 2017', fontweight ="bold",)
plt.xticks(rotation=90)
plt.show()

# %%
data_transaksi['Date'] = pd.to_datetime(data_transaksi['Date'])
data_transaksi['year'] = data_transaksi['Date'].dt.year
data_transaksi['month'] = data_transaksi['Date'].dt.month_name()

data_year = data_transaksi[data_transaksi['year'] == 2017]
data_year

data_may = data_year [data_year['month']=='May']
data_may

plt.scatter(data_may['Quantity'], data_may['Date'])

plt.xlabel('Quantity')
plt.ylabel('Date')
plt.title('Transaksi pada Bulan May 2017', fontweight ="bold",)
plt.show()
